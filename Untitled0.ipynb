# %% [markdown]
# <a href="https://colab.research.google.com/github/jinq23/test/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #test
# 1.aaa
# 2.bbb
# 3.ccc
# [yahoo](https://www.yahoo.tw)
# ![台灣黑熊](bear.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
print ('hello')
def f(x):print(x)
interact(f, x=3)
# Out:
# hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-01ca7284a656> in <module>()
#       1 print ('hello')
#       2 def f(x):print(x)
# ----> 3 interact(f, x=3)
#
# NameError: name 'interact' is not defined

# %%
grades = np.array([85, 70, 80])
weights = np.array([0.2, 0.35, 0.45])
np.dot(grades, weights)
# Out:
# 77.5

# %% [markdown]
# #5555

# %%
df = pd.read_csv("http://bit.ly/gradescsv")
#df.head()
#df.國文
#cg = df.國文.values
df.國文.plot()

# %%
df.國文.plot(kind='hist')

# %%
df["總級分"] = df.sum(axis=1)
df["加權"]=df.國文+df.英文+df.數學*2
df.head()
#df.sort_values(by="總級分", ascending=False).head(10)
df.sort_values(by=["加權","總級分"], ascending=False).head(10)
df.reindex(range(1,101))
# Out:
#       姓名    國文    英文    數學    自然    社會     總級分    加權
# 1    胡玉華  10.0  10.0  10.0   8.0   9.0  1493.0  40.0
# 2    黃淑婷  13.0  15.0   8.0  11.0  14.0  1819.0  44.0
# 3    陳上紫  10.0  10.0   8.0   9.0  14.0  1509.0  36.0
# 4    崔靜成  13.0  12.0  14.0  12.0  13.0  2011.0  53.0
# 5    張雅岳  13.0  12.0  12.0  12.0   8.0  1818.0  49.0
# 6    梁俊翔  11.0  13.0  10.0  10.0  14.0  1762.0  44.0
# 7    林金鳳   8.0   9.0  10.0  10.0   8.0  1410.0  37.0
# 8    許協旺   9.0   9.0  12.0  10.0  10.0  1580.0  42.0
# 9    郭雅惠  10.0  15.0  12.0  11.0   9.0  1818.0  49.0
# 10   張志偉  14.0   9.0   8.0  10.0  12.0  1592.0  39.0
# 11   周皇樺  13.0   9.0  13.0  14.0  15.0  1936.0  48.0
# 12   李正偉  11.0  15.0  11.0  14.0  15.0  1974.0  48.0
# 13   黃旭忠  15.0  14.0   9.0  12.0  10.0  1845.0  47.0
# 14   葉雅琳   8.0  13.0  10.0  13.0  14.0  1717.0  41.0
# 15   黃淑慧  11.0   8.0  10.0  12.0  15.0  1649.0  39.0
# 16   吳芝菁  14.0   9.0  11.0  10.0   9.0  1682.0  45.0
# 17   聶珮君  12.0  11.0  13.0  12.0   9.0  1818.0  49.0
# ...

# %%
import pandas_datareader as pdr
df1 = pdr.get_data_yahoo('AAPL')
df1 = df[-300:]
df1.Close.plot()
df1.Close.rolling(20).mean().plot()

# %%
df.Close.plot(legend=True)
df.Close.rolling(20).mean().plot(label="$MA_{20}$", legend=True)
df.Close.rolling(60).mean().plot(label="$MA_{60}$", legend=True)

# %%
adj_close = df.Close.values
X = adj_close[:-1]
Y = adj_close[1:]
plt.scatter(X,Y,alpha=0.5)
